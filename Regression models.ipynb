# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib .pyplot as plt #importing info into graphs
# %matplotlib inline
import seaborn as sns #for pretty/more detailed graphs
import scipy.stats as stats
pd.set_option('display.max_columns',None) #gives space so i can view all of the collumns

# %%
file1= pd.read_csv('/Users/hpb/PycharmProjects/Ironhack/Unit4_lab-cleaning-numerical-data-master/files_for_lab/autoinsurance.csv')

# %%
column_names=file1.columns 
data=pd.DataFrame(columns=column_names) 
customer_df=pd.concat([data,file1],axis=0)

# %%
customer_df['Effective To Date']=pd.to_datetime(customer_df['Effective To Date'], errors='coerce') #Change object to Datetime format.

# %%
def clean_data(df):
    df.columns=[e.lower().replace(' ', '_') for e in df.columns] #lowercase and replace white space.
    return df
clean_data(customer_df)
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender income location_code  \
# ...

# %%
round(customer_df.isna().sum()/len(customer_df),4)*100 #check for nulls in all values
# Out:
# customer                         0.0
# state                            0.0
# customer_lifetime_value          0.0
# response                         0.0
# coverage                         0.0
# education                        0.0
# effective_to_date                0.0
# employmentstatus                 0.0
# gender                           0.0
# income                           0.0
# location_code                    0.0
# marital_status                   0.0
# monthly_premium_auto             0.0
# months_since_last_claim          0.0
# months_since_policy_inception    0.0
# number_of_open_complaints        0.0
# number_of_policies               0.0
# policy_type                      0.0
# policy                           0.0
# renew_offer_type                 0.0
# sales_channel                    0.0
# total_claim_amount               0.0
# vehicle_class                    0.0
# vehicle_size                     0.0
# dtype: float64

# %%
customer_df.describe() #no NaN but to further check we use the describe function.
#number of open complaints and income have 0's.
# Out:
#        customer_lifetime_value  total_claim_amount
# count              9134.000000         9134.000000
# mean               8004.940475          434.088794
# std                6870.967608          290.500092
# min                1898.007675            0.099007
# 25%                3994.251794          272.258244
# 50%                5780.182197          383.945434
# 75%                8962.167041          547.514839
# max               83325.381190         2893.239678

# %%
mean_income=customer_df['income'].mean(skipna=True)
customer_df['income']=customer_df.income.mask(customer_df.income==0,mean_income) #replace null incomes with the mean

# %%
numericals = customer_df.select_dtypes(np.number)
numericals
# Out:
#       customer_lifetime_value  total_claim_amount
# 0                 2763.519279          384.811147
# 1                 6979.535903         1131.464935
# 2                12887.431650          566.472247
# 3                 7645.861827          529.881344
# 4                 2813.692575          138.130879
# ...                       ...                 ...
# 9129             23405.987980          198.234764
# 9130              3096.511217          379.200000
# 9131              8163.890428          790.784983
# 9132              7524.442436          691.200000
# 9133              2611.836866          369.600000
#
# [9134 rows x 2 columns]

# %%
customer_df[["income","months_since_policy_inception","months_since_policy_inception","monthly_premium_auto","months_since_last_claim", "number_of_open_complaints", "number_of_policies"]] = customer_df[["income","months_since_policy_inception","months_since_policy_inception", "monthly_premium_auto","months_since_last_claim", "number_of_open_complaints", "number_of_policies"]].apply(pd.to_numeric)

# %%
numericals = customer_df.select_dtypes(np.number)
numericals
# Out:
#       customer_lifetime_value        income  monthly_premium_auto  \
# 0                 2763.519279  56274.000000                    69
# 1                 6979.535903  37657.380009                    94
# 2                12887.431650  48767.000000                   108
# 3                 7645.861827  37657.380009                   106
# 4                 2813.692575  43836.000000                    73
# ...                       ...           ...                   ...
# 9129             23405.987980  71941.000000                    73
# 9130              3096.511217  21604.000000                    79
# 9131              8163.890428  37657.380009                    85
# 9132              7524.442436  21941.000000                    96
# 9133              2611.836866  37657.380009                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# ...

# %%
discrete = [i for i in numericals if (len(numericals[i].unique()) < (numericals.shape[0] * 0.01))]
discrete
# Out:
# ['months_since_last_claim', 'number_of_open_complaints', 'number_of_policies']

# %%
discrete_df=customer_df[discrete]

# %%
continuous = list(numericals.drop(columns = discrete).columns) #drop discrete values
continuous
# Out:
# ['customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_policy_inception',
#  'total_claim_amount']

# %%
def outliers(column, threshold = 3): #a function to find outliers
    data = column[abs(column.apply(lambda x: (x - column.mean()) / column.var() ** (1/2))) > threshold]
    return data

# %%
CLV_outliers = outliers(customer_df["customer_lifetime_value"])
MPA_outliers = outliers(customer_df["monthly_premium_auto"])

# %%
to_drop = CLV_outliers.index | MPA_outliers.index # Union

# %%
clean_customer_df = customer_df.drop(to_drop).reset_index(drop = True) #dropped the outliers and reset the index
clean_customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 8748  LA72316  California             23405.987980       No     Basic
# 8749  PK87824  California              3096.511217      Yes  Extended
# 8750  TD14365  California              8163.890428       No  Extended
# 8751  UP19263  California              7524.442436       No  Extended
# 8752  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender        income  \
# ...

# %%
clean_customer_df[continuous].head()
# Out:
#    customer_lifetime_value        income  monthly_premium_auto  \
# 0              2763.519279  56274.000000                    69
# 1              6979.535903  37657.380009                    94
# 2             12887.431650  48767.000000                   108
# 3              7645.861827  37657.380009                   106
# 4              2813.692575  43836.000000                    73
#
#    months_since_policy_inception  total_claim_amount
# 0                              5          384.811147
# 1                             42         1131.464935
# 2                             38          566.472247
# 3                             65          529.881344
# 4                             44          138.130879

# %%
continuous.remove("months_since_policy_inception")
continuous.remove("total_claim_amount")

# %%
clean_customer_df[continuous].head()
# Out:
#    customer_lifetime_value        income  monthly_premium_auto
# 0              2763.519279  56274.000000                    69
# 1              6979.535903  37657.380009                    94
# 2             12887.431650  48767.000000                   108
# 3              7645.861827  37657.380009                   106
# 4              2813.692575  43836.000000                    73

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# %%
columns = clean_customer_df[continuous].columns      # must be done in the same dataframe, I was creating multiple which was causing an issue

def scale_data(data, columns, scaler):
    for col in columns:
        data[col] = scaler.fit_transform(data[col].values.reshape(-1, 1))
    return data

scale_data(clean_customer_df, columns, StandardScaler())
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington                -0.903549       No     Basic
# 1     QZ44356     Arizona                -0.036574       No  Extended
# 2     AI49188      Nevada                 1.178317       No   Premium
# 3     WW63253  California                 0.100449       No     Basic
# 4     HB64268  Washington                -0.893231       No     Basic
# ...       ...         ...                      ...      ...       ...
# 8748  LA72316  California                 3.341336       No     Basic
# 8749  PK87824  California                -0.835073      Yes  Extended
# 8750  TD14365  California                 0.206975       No  Extended
# 8751  UP19263  California                 0.075480       No  Extended
# 8752  Y167826  California                -0.934741       No  Extended
#
#      education effective_to_date employmentstatus gender    income  \
# ...

# %%
#exploration and visualisation done in other workbook (Cleaning numerical & categorical data)

# %%
#Manually dropping outliers - this caused a problem with the index
#continuous_df = numericals.drop(columns = discrete)

# %%
#q3 = continuous_df['monthly_premium_auto'].quantile(.75)
#q1 = continuous_df['monthly_premium_auto'].quantile(.25)

# calculating the interquartile range
#iqr = q3 - q1

# calculating the median
#median = continuous_df['monthly_premium_auto'].median()

# defining the upper limit of the data according to the 1.5*IQR rule
#outlier_limit_upper = median + 1.5*iqr

# defining the lower limit of the data according to the 1.5*IQR rule
#outlier_limit_lower = median - 1.5*iqr

#outlier_limit_upper

# %%
#continuous_df= continuous_df[continuous_df['monthly_premium_auto'] < outlier_limit_upper] #getting rid of outliers

# %%
#q3 = continuous_df['customer_lifetime_value'].quantile(.75)
#q1 = continuous_df['customer_lifetime_value'].quantile(.25)

# calculating the interquartile range
#iqr = q3 - q1

# calculating the median
#median = continuous_df['customer_lifetime_value'].median()

# defining the upper limit of the data according to the 1.5*IQR rule
#outlier_limit_upper = median + 1.5*iqr

# defining the lower limit of the data according to the 1.5*IQR rule
#outlier_limit_lower = median - 1.5*iqr

#outlier_limit_upper

# %%
#continuous_df= continuous_df[continuous_df['customer_lifetime_value'] < outlier_limit_upper]

# %%
categorical = customer_df.select_dtypes(np.object)

# %%
categorical.nunique() #check unique values to see if there is any categorical with too much data
# Out:
# customer            9134
# state                  5
# response               2
# coverage               3
# education              5
# employmentstatus       5
# gender                 2
# location_code          3
# marital_status         3
# policy_type            3
# policy                 9
# renew_offer_type       4
# sales_channel          4
# vehicle_class          6
# vehicle_size           3
# dtype: int64

# %%
categorical_columns = [i for i in categorical if (len(categorical[i].unique()) < (numericals.shape[0] * 0.01))]

# %%
#categorical_df=customer_df[categorical_columns] #defines a new data frame with just categoricals with binary/few options

# %%
#cat_df= categorical_df.copy()

# %%
pip install category_encoders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder

#ordinal = clean_customer_df.drop(columns = "customer")
one_hot = clean_customer_df

import category_encoders as ce

one_hot_colums = one_hot.select_dtypes(include = object).columns[1:]
clean_customer_df = pd.get_dummies(one_hot, columns = one_hot_colums)

# %%
final_df= clean_customer_df.drop(columns="customer")
final_df= final_df.drop(columns="effective_to_date")

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(final_df.drop(columns = "total_claim_amount"),
                                                    final_df.total_claim_amount, test_size = 0.2)

# %%
np.asarray(final_df)
# Out:
# array([[-0.90354879,  0.41447267, -0.75438534, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.03657369, -0.43969764,  0.16509717, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.1783168 ,  0.07003547,  0.68000737, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.20697514, -0.43969764, -0.16591654, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.07548005, -1.16079875,  0.23865577, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.93474052, -0.43969764, -0.46015094, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
final_df.apply(pd.to_numeric) #error flagged saying it was the wrong data type (object)
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                   -0.903549  0.414473             -0.754385
# 1                   -0.036574 -0.439698              0.165097
# 2                    1.178317  0.070035              0.680007
# 3                    0.100449 -0.439698              0.606449
# 4                   -0.893231 -0.156209             -0.607268
# ...                       ...       ...                   ...
# 8748                 3.341336  1.133308             -0.607268
# 8749                -0.835073 -1.176261             -0.386592
# 8750                 0.206975 -0.439698             -0.165917
# 8751                 0.075480 -1.160799              0.238656
# 8752                -0.934741 -0.439698             -0.460151
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
np.asarray(final_df)
# Out:
# array([[-0.90354879,  0.41447267, -0.75438534, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.03657369, -0.43969764,  0.16509717, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.1783168 ,  0.07003547,  0.68000737, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.20697514, -0.43969764, -0.16591654, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.07548005, -1.16079875,  0.23865577, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.93474052, -0.43969764, -0.46015094, ...,  0.        ,
#          1.        ,  0.        ]])

# %%
#X_train.astype(int).fit() - had to add this extra to the model because date time was throwing it out of balance - however ended up not functioning properly anyway so removed datetime.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

X_train_wi=sm.add_constant(X_train)
model=sm.OLS(y_train,X_train_wi).fit() #had to add this extra bit .astype(int) for it to work 



print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     total_claim_amount   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     440.9
# Date:                Fri, 13 Nov 2020   Prob (F-statistic):               0.00
# Time:                        23:25:09   Log-Likelihood:                -43964.
# No. Observations:                7002   AIC:                         8.803e+04
# Df Residuals:                    6953   BIC:                         8.836e+04
# Df Model:                          48
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression as LinReg

linreg=LinReg()    
linreg.fit(X_train, y_train)   
y_pred_linreg=linreg.predict(X_test)

# %%
print ('train R2: {} -- test R2: {}'.format(linreg.score(X_train, y_train),
                                            linreg.score(X_test, y_test)))
# Out:
# train R2: 0.7526957984184204 -- test R2: 0.7459324641534346

# %%
from sklearn.metrics import mean_squared_error as mse


train_mse=mse(linreg.predict(X_train), y_train)
test_mse=mse(linreg.predict(X_test), y_test)

print ('train MSE: {} -- test MSE: {}'.format(train_mse, test_mse))
# Out:
# train MSE: 16642.869433768108 -- test MSE: 16113.365661777241

# %%
print ('train RMSE: {} -- test RMSE: {}'.format(train_mse**.5, test_mse**.5))
# Out:
# train RMSE: 129.00724566383124 -- test RMSE: 126.93843256388998

# %%
from sklearn.metrics import mean_absolute_error as mae

train_mae=mae(linreg.predict(X_train), y_train)
test_mae=mae(linreg.predict(X_test), y_test)

print ('train MAE: {} -- test MAE: {}'.format(train_mse, test_mse))
# Out:
# train MAE: 16642.869433768108 -- test MAE: 16113.365661777241

# %%
from sklearn.linear_model import Lasso, Ridge, ElasticNet, SGDRegressor

# %%
def models_automation(models, X_train, y_train):
    for model in models:
        model.fit(X_train, y_train)
        print(f"{model.__class__.__name__}: Train -> {model.score(X_train, y_train)}, Test -> {model.score(X_test, y_test)}")

linear_models = [Lasso(), Ridge(), ElasticNet()]
models_automation(linear_models, X_train, y_train)
# Out:
# Lasso: Train -> 0.7500062749126017, Test -> 0.7443665720060779
# Ridge: Train -> 0.7526955721875579, Test -> 0.7459482032112927
# ElasticNet: Train -> 0.5966741967658129, Test -> 0.5937985900673901
