# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
# Get csv files

file1 = pd.read_csv('/Users/siriamanda/Desktop/Ironhack/data-analytics/week-1-2/lab-1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file1.csv')
file2 = pd.read_csv('/Users/siriamanda/Desktop/Ironhack/data-analytics/week-1-2/lab-1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file2.csv')
file3 = pd.read_csv('/Users/siriamanda/Desktop/Ironhack/data-analytics/week-1-2/lab-1/lab-customer-analysis-round-1-master/files_for_lab/csv_files/file3.csv')

# %%
# Show the DataFrames shape

print(file1.shape)
print(file2.shape)
print(file3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
# Standardize header names

# File 1
cols_1 = []                    # Create an empty list
for i in range(len(file1.columns)):
    cols_1.append(file1.columns[i].lower().replace(' ', '_'))
file1.columns = cols_1

# File 2
cols_2 = []                    # Create an empty list
for i in range(len(file2.columns)):
    cols_2.append(file2.columns[i].lower().replace(' ', '_'))
file2.columns = cols_2

# File 3
cols_3 = []                    # Create an empty list
for i in range(len(file3.columns)):
    cols_3.append(file3.columns[i].lower().replace(' ', '_'))
file3.columns = cols_3

file1 = file1.rename(columns = {'state': 'st'})
file3 = file3.rename(columns = {'state': 'st'})

# %%
file1.columns
# Out:
# Index(['customer', 'st', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['customer', 'st', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
# Rearrange the columns in the DataFrame

file2 = file2[file1.columns]       # Let columns in file 2 and 3 mirror the columns in file 1

file3 = file3[file1.columns]

# %%
# Concenate the three dataframes

column_names = file1.columns
column_names

data = pd.DataFrame(columns = column_names)                     # Add the column names
data

data = pd.concat([data, file1, file2, file3], axis = 0)         # Concat the three files vertically 
data.shape
# Out:
# (12074, 11)

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# customer_lifetime_value       object
# education                     object
# gender                        object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# total_claim_amount            object
# vehicle_class                 object
# dtype: object

# %%
# Numerical columner

data.select_dtypes('float')
# Out:
#        income  monthly_premium_auto
# 0         0.0                1000.0
# 1         0.0                  94.0
# 2     48767.0                 108.0
# 3         0.0                 106.0
# 4     36357.0                  68.0
# ...       ...                   ...
# 7065  71941.0                  73.0
# 7066  21604.0                  79.0
# 7067      0.0                  85.0
# 7068  21941.0                  96.0
# 7069      0.0                  77.0
#
# [12074 rows x 2 columns]

# %%
# Categorical columner

data.select_dtypes('object')
# Out:
#      customer          st customer_lifetime_value             education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona                       F              Bachelor
# 2     AI49188      Nevada                       F              Bachelor
# 3     WW63253  California                       M              Bachelor
# 4     GA49547  Washington                       M  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California                   23406              Bachelor
# 7066  PK87824  California                 3096.51               College
# 7067  TD14365  California                 8163.89              Bachelor
# 7068  UP19263  California                 7524.44               College
# 7069  Y167826  California                 2611.84               College
#
#            gender number_of_open_complaints     policy_type  \
# 0             NaN                    1/0/00   Personal Auto
# 1      697953.59%                    1/0/00   Personal Auto
# 2     1288743.17%                    1/0/00   Personal Auto
# 3      764586.18%                    1/0/00  Corporate Auto
# 4      536307.65%                    1/0/00   Personal Auto
# ...           ...                       ...             ...
# 7065            M                         0   Personal Auto
# 7066            F                         0  Corporate Auto
# 7067            M                         3  Corporate Auto
# 7068            M                         0   Personal Auto
# 7069            M                         0  Corporate Auto
#
#      total_claim_amount  vehicle_class
# 0         Four-Door Car        2.70493
# 1         Four-Door Car        1131.46
# 2          Two-Door Car        566.472
# 3                   SUV        529.881
# 4         Four-Door Car        17.2693
# ...                 ...            ...
# 7065            198.235  Four-Door Car
# 7066              379.2  Four-Door Car
# 7067            790.785  Four-Door Car
# 7068              691.2  Four-Door Car
# 7069              369.6   Two-Door Car
#
# [12074 rows x 9 columns]

# %%
# Perform data cleaning operations mentioned so far

# Delete 'education' and 'number_of_open_complaints' from the dataframe with drop

data = data.drop(['education', 'number_of_open_complaints'], axis=1)
data
# Out:
#      customer          st customer_lifetime_value       gender   income  \
# 0     RB50392  Washington                     NaN          NaN      0.0
# 1     QZ44356     Arizona                       F   697953.59%      0.0
# 2     AI49188      Nevada                       F  1288743.17%  48767.0
# 3     WW63253  California                       M   764586.18%      0.0
# 4     GA49547  Washington                       M   536307.65%  36357.0
# ...       ...         ...                     ...          ...      ...
# 7065  LA72316  California                   23406            M  71941.0
# 7066  PK87824  California                 3096.51            F  21604.0
# 7067  TD14365  California                 8163.89            M      0.0
# 7068  UP19263  California                 7524.44            M  21941.0
# 7069  Y167826  California                 2611.84            M      0.0
#
#       monthly_premium_auto     policy_type total_claim_amount  vehicle_class
# 0                   1000.0   Personal Auto      Four-Door Car        2.70493
# 1                     94.0   Personal Auto      Four-Door Car        1131.46
# 2                    108.0   Personal Auto       Two-Door Car        566.472
# 3                    106.0  Corporate Auto                SUV        529.881
# 4                     68.0   Personal Auto      Four-Door Car        17.2693
# ...                    ...             ...                ...            ...
# 7065                  73.0   Personal Auto            198.235  Four-Door Car
# 7066                  79.0  Corporate Auto              379.2  Four-Door Car
# 7067                  85.0  Corporate Auto            790.785  Four-Door Car
# 7068                  96.0   Personal Auto              691.2  Four-Door Car
# 7069                  77.0  Corporate Auto              369.6   Two-Door Car
#
# [12074 rows x 9 columns]

# %%
# Correct the values in the column `customer_lifetime_value
# Multiply them by 100 and change `dtype` to numerical type

data['customer_lifetime_value'] = data['customer_lifetime_value']*100
data['customer_lifetime_value'] =  pd.to_numeric(data['customer_lifetime_value'], errors='coerce')

# %%
# Remove duplicate rows if any

data.shape
# Out:
# (9138, 9)

# %%
data = data.drop_duplicates()           # drop_duplicates remove duplicates rows

# %%
data.shape
# Out:
# (9138, 9)

# %%
# Filter data for customers who have an income of 0 or less

data = data[data['income'] <= 0]
data
# Out:
#      customer          st  customer_lifetime_value      gender  income  \
# 0     RB50392  Washington                      NaN         NaN     0.0
# 1     QZ44356     Arizona                      NaN  697953.59%     0.0
# 3     WW63253  California                      NaN  764586.18%     0.0
# 7     CF85061     Arizona                      NaN  721610.03%     0.0
# 10    SX51350  California                      NaN  473899.20%     0.0
# ...       ...         ...                      ...         ...     ...
# 7059  WZ45103  California             5.678050e+05           F     0.0
# 7061  RX91025  California             1.987226e+06           M     0.0
# 7062  AC13887  California             4.628995e+05           M     0.0
# 7067  TD14365  California             8.163890e+05           M     0.0
# 7069  Y167826  California             2.611837e+05           M     0.0
#
#       monthly_premium_auto     policy_type total_claim_amount  vehicle_class
# 0                   1000.0   Personal Auto      Four-Door Car        2.70493
# 1                     94.0   Personal Auto      Four-Door Car        1131.46
# 3                    106.0  Corporate Auto                SUV        529.881
# 7                    101.0  Corporate Auto      Four-Door Car         363.03
# 10                    67.0   Personal Auto      Four-Door Car          482.4
# ...                    ...             ...                ...            ...
# 7059                  76.0   Personal Auto              364.8  Four-Door Car
# 7061                 185.0   Personal Auto            1950.73            SUV
# 7062                  67.0  Corporate Auto              482.4   Two-Door Car
# 7067                  85.0  Corporate Auto            790.785  Four-Door Car
# 7069                  77.0  Corporate Auto              369.6   Two-Door Car
#
# [2294 rows x 9 columns]

# %%
# Get numeric data

data_num = data._get_numeric_data()
data_num.head()
# Out:
#     customer_lifetime_value  income  monthly_premium_auto
# 0                       NaN     0.0                1000.0
# 1                       NaN     0.0                  94.0
# 3                       NaN     0.0                 106.0
# 7                       NaN     0.0                 101.0
# 10                      NaN     0.0                  67.0

# %%
# Check normality 

sns.pairplot(data)
data_num.describe()
# Out:
#        customer_lifetime_value  income  monthly_premium_auto
# count             1.821000e+03  2294.0           2294.000000
# mean              7.687005e+05     0.0             98.663906
# std               6.626634e+05     0.0            214.531408
# min               1.898008e+05     0.0             61.000000
# 25%               3.740404e+05     0.0             69.000000
# 50%               5.619689e+05     0.0             84.000000
# 75%               8.708019e+05     0.0            110.000000
# max               6.461876e+06     0.0          10202.000000

# %%
# Check multicollinearity

mask = np.zeros_like(data.corr())
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(data.corr(), mask=mask, annot=True)
plt.show()

# %%
# Get the data

data1 = pd.read_csv('/Users/siriamanda/Desktop/Ironhack/data-analytics/week-1-3/lab-1/lab-customer-analysis-round-3-master/files_for_lab/csv_files/marketing_customer_analysis.csv')      # import csv file
data1.head() # show first 5 rows
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
data1.columns = [e.lower().replace(' ', '_') for e in file1.columns]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7edf7e233a57> in <module>
# ----> 1 data1.columns = [e.lower().replace(' ', '_') for e in file1.columns]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 24 elements, new values have 11 elements

# %%
def clean_data(df):
    df.columns = [e.lower().replace(' ', '_') for e in df.columns]
    df = df.drop(columns = ['unnamed:_0', 'vehicle_type'])
    df = df.dropna()
    df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], errors = 'coerce')
    return df

data = clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'effective_to_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c5df73dd3246> in <module>
#       5     return df
#       6
# ----> 7 data = clean_data(data)
#
# <ipython-input-63-c5df73dd3246> in clean_data(df)
#       2     df.columns = [e.lower().replace(' ', '_') for e in df.columns]
#       3     df = df.dropna()
# ----> 4     df['effective_to_date'] = pd.to_datetime(df['effective_to_date'], errors = 'coerce')
#       5     return df
#       6
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'effective_to_date'
