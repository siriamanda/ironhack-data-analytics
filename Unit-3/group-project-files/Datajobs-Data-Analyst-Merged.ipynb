# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt
import itertools
plt.style.use('ggplot')

# %%
data = pd.read_csv('merged.csv')

# %%
data.shape
# Out:
# (4099, 11)

# %%
data['description'].describe()
# Out:
# count                                                  4099
# unique                                                 3747
# top       Innovate. Collaborate. Shine. Lighthouse — KPM...
# freq                                                     10
# Name: description, dtype: object

# %%
data.isnull().any()
# Out:
# ID             False
# position       False
# company        False
# reviews         True
# location       False
# zip_code        True
# description    False
# name           False
# size           False
# industry       False
# country        False
# dtype: bool

# %%
data.head()
# Out:
#      ID                                           position       company  \
# 0  5317               Field Application Scientist - Boston  10x Genomics
# 1  3124                               Validation Scientist       23andMe
# 2  1559  Scientist / Senior Scientist - Computational B...       23andMe
# 3  3076          Population Geneticist - Ancestry Research       23andMe
# 4  2764             Senior Product Manager, Research Tools       23andMe
#
#    reviews       location  zip_code  \
# 0      NaN         Boston       NaN
# 1      4.0  Mountain View   94041.0
# 2      4.0  Mountain View   94041.0
# 3      4.0  Mountain View   94041.0
# 4      4.0  Mountain View   94041.0
#
#                                          description          name      size  \
# 0  Region: Boston\n\nThe Field Applications Scien...  10x genomics   201-500
# 1  23andMe is seeking a talented Validation Scien...       23andme  501-1000
# 2  With the world’s largest database of more than...       23andme  501-1000
# 3  We are seeking colleagues with extensive train...       23andme  501-1000
# 4  Who we are\n\n23andMe’s mission is to help ind...       23andme  501-1000
#
#         industry        country
# 0  biotechnology  united states
# 1  biotechnology  united states
# 2  biotechnology  united states
# 3  biotechnology  united states
# 4  biotechnology  united states

# %%
# Group listings for data analysts 

data_analyst = data[data['position'].str.contains("Data Analyst|Data analyst|data analyst|Analyst|analyst]")] 

data_analyst.head()
# Out:
#       ID                                          position          company  \
# 5   2448  Senior Financial Analyst, Research & Development          23andMe
# 23  4122                           Data Analyst / Engineer       7Park Data
# 26  2570                    Quantitative Marketing Analyst  A Place for Mom
# 29  2551     Web Analyst & Technical Editor, AARP Research             AARP
# 46  4957                            Data Reporting Analyst             ACLU
#
#     reviews       location  zip_code  \
# 5       4.0  Mountain View   94041.0
# 23      NaN       New York       NaN
# 26    105.0        Seattle       NaN
# 29    889.0     Washington   20001.0
# 46     70.0       New York       NaN
#
#                                           description             name  \
# 5   Reporting to the Director of Financial Plannin...          23andme
# 23  Data Analyst / Engineer\n\nThe Data Analyst / ...       7park data
# 26  OVERVIEW\nAPFM is looking for a passionate mar...  a place for mom
# 29  Business Unit Description\n\n\nAARP is a nonpr...             aarp
# 46  The ACLU is seeking a full-time Data Reporting...             aclu
#
#           size                            industry        country
# 5     501-1000                       biotechnology  united states
# 23      51-200                information services  united states
# 26   1001-5000              hospital & health care  united states
# 29  5001-10000  non-profit organization management  united states
# 46   1001-5000  non-profit organization management  united states

# %%
data_analyst.shape
# Out:
# (511, 11)

# %%
# Group listings for data scientists

data_scientist = data[data['position'].str.contains("Data Scientist|Data scientist|data scientist|Scientist|scientist")] 

data_scientist.head()
# Out:
#      ID                                           position       company  \
# 0  5317               Field Application Scientist - Boston  10x Genomics
# 1  3124                               Validation Scientist       23andMe
# 2  1559  Scientist / Senior Scientist - Computational B...       23andMe
# 6  2038                                     Data Scientist       23andMe
# 7  6898         Scientist, Bioanalytical Assay Development       23andMe
#
#    reviews             location  zip_code  \
# 0      NaN               Boston       NaN
# 1      4.0        Mountain View   94041.0
# 2      4.0        Mountain View   94041.0
# 6      4.0        Mountain View   94041.0
# 7      4.0  South San Francisco       NaN
#
#                                          description          name      size  \
# 0  Region: Boston\n\nThe Field Applications Scien...  10x genomics   201-500
# 1  23andMe is seeking a talented Validation Scien...       23andme  501-1000
# 2  With the world’s largest database of more than...       23andme  501-1000
# 6  23andMe is seeking an experienced data scienti...       23andme  501-1000
# 7  Who we are\n\nSince 2006, 23andMe’s mission ha...       23andme  501-1000
#
#         industry        country
# 0  biotechnology  united states
# 1  biotechnology  united states
# 2  biotechnology  united states
# 6  biotechnology  united states
# 7  biotechnology  united states

# %%
data_scientist.shape
# Out:
# (1524, 11)

# %%
# Group listings for engineers

engineer = data[data['position'].str.contains("Engineer|engineer|Programmer|programmer|Developer|developer")] 

engineer.head()
# Out:
#       ID                                           position     company  \
# 12   233              Software Engineer - Genetics Platform     23andMe
# 17  3887  Senior Software Engineer - Machine Learning as...     23andMe
# 23  4122                            Data Analyst / Engineer  7Park Data
# 31   650                                      Data Engineer      AbbVie
# 39  5531       Data Scientist II – Bioinformatics Developer      AbbVie
#
#     reviews       location  zip_code  \
# 12      4.0  Mountain View   94041.0
# 17      4.0  Mountain View   94041.0
# 23      NaN       New York       NaN
# 31    596.0        Chicago       NaN
# 39    596.0      Cambridge       NaN
#
#                                           description        name      size  \
# 12  Join 23andMe in our mission is to be the world...     23andme  501-1000
# 17  Join 23andMe and solve engineering problems to...     23andme  501-1000
# 23  Data Analyst / Engineer\n\nThe Data Analyst / ...  7park data    51-200
# 31  For large enterprise datasets, the data engine...      abbvie    10001+
# 39  The Scientific Informatics group at the AbbVie...      abbvie    10001+
#
#                 industry        country
# 12         biotechnology  united states
# 17         biotechnology  united states
# 23  information services  united states
# 31       pharmaceuticals  united states
# 39       pharmaceuticals  united states

# %%
engineer.shape
# Out:
# (929, 11)

# %%
# Create an array with the descriptions for each position

analyst_text = data_analyst.description.values
scientist_text = data_scientist.description.values
engineer_text = engineer.description.values

# %%
# Skills requirements

# Define a regex search function for Data Analyst

def count_text(patt,text):
    pattern = re.compile(patt)
    count = 0
    for t in text:
        if pattern.search(t):
            count+=1
    return count

# %%
# Create a data frame with skills name and regex pattern to search with

# Technical skills

tech_skills = ['R','Python','Hadoop','SQL','Tableau','TensorFlow','Agile','Power BI','Algorithm','Java','Visualization', 'PHP', 'Excel']

tech_skill_patt = ['\WR\W+\s*','(?i)\WPython\W','(?i)\WHadoop\W?','(?i)SQL\w*','(?i)\WTableau\W?',
              "(?i)\WTensorFlow\W?","(?i)\WAgile\W?","(?i)\WPower\s?BI\W?",
              "(?i)\WAlgorithms?\W?",'(?i)Java\w*','(?i)\WVisualization\W?', '(?i)\WPHP\W?', '(?i)\WExcel\W?']

tech_skill_df =pd.DataFrame(
    {"skill": tech_skills,
     "regex_pattern":tech_skill_patt})

# %%
# Iterate through the list of skills using the search function created

i = []
for x in tech_skill_df['regex_pattern']:
    i.append(count_text(x,analyst_text))
tech_skill_df['count'] = i
tech_skill_df['ptg'] = round(tech_skill_df['count']/len(analyst_text),2)
tech_skill_df
# Out:
#             skill           regex_pattern  count   ptg
# 0               R               \WR\W+\s*    183  0.36
# 1          Python          (?i)\WPython\W    158  0.31
# 2          Hadoop         (?i)\WHadoop\W?     21  0.04
# 3             SQL              (?i)SQL\w*    196  0.38
# 4         Tableau        (?i)\WTableau\W?     82  0.16
# 5      TensorFlow     (?i)\WTensorFlow\W?      1  0.00
# 6           Agile          (?i)\WAgile\W?     21  0.04
# 7        Power BI     (?i)\WPower\s?BI\W?     14  0.03
# 8       Algorithm    (?i)\WAlgorithms?\W?     44  0.09
# 9            Java             (?i)Java\w*     43  0.08
# 10  Visualization  (?i)\WVisualization\W?     96  0.19
# 11            PHP            (?i)\WPHP\W?      8  0.02
# 12          Excel          (?i)\WExcel\W?    335  0.66

# %%
# Plot the skills as a percentage from all listings for Data Analysts 

x = tech_skill_df.sort_values(by = 'ptg')
ax =x['ptg'].plot(kind = "barh",figsize = (10,5))
ax.set_title('Skills as Percentage of Total Job Description', size = 15)
ax.set_yticklabels(x['skill'], size = 12)
ax.set_xticklabels(['{:.0%}'.format(x) for x in ax.get_xticks()])
plt.show()

# %%
# Soft skills

soft_skills = ['Communication','Teamwork','Research', 'Work ethic', 'Problem solving', 'Independent', 'Presentation', 'Confidence', 'Leadership skills', 'Interpersonal skills', 'Time Management', 'Critical Thinking', 'Adaptability']

soft_skill_patt = ['(?i)\WCommunication\W','(?i)\WTeamwork\W','(?i)\WResearch\W', '(?i)\WWork ethic\W', '(?i)\WProblem solving\W', '(?i)\WIndependent\W', '(?i)\WPresentation\W', '(?i)\WConfidence\W', '(?i)\WLeadership skills\W', '(?i)\WInterpersonal skills\W', '(?i)\WTime Management\W', '(?i)\WCritical Thinking\W', '(?i)\WAdaptability\W']

soft_skill_df = pd.DataFrame(
    {"skill": soft_skills,
     "regex_pattern": soft_skill_patt})

# %%
# Iterate through the list of skills using the search function created

j = []
for x in soft_skill_df['regex_pattern']:
    j.append(count_text(x,analyst_text))
soft_skill_df['count'] = j
soft_skill_df['ptg'] = round(soft_skill_df['count']/len(analyst_text),2)
soft_skill_df
# Out:
#                    skill                 regex_pattern  count   ptg
# 0          Communication         (?i)\WCommunication\W    278  0.54
# 1               Teamwork              (?i)\WTeamwork\W     29  0.06
# 2               Research              (?i)\WResearch\W    325  0.64
# 3             Work ethic            (?i)\WWork ethic\W     16  0.03
# 4        Problem solving       (?i)\WProblem solving\W     72  0.14
# 5            Independent           (?i)\WIndependent\W     58  0.11
# 6           Presentation          (?i)\WPresentation\W     81  0.16
# 7             Confidence            (?i)\WConfidence\W     13  0.03
# 8      Leadership skills     (?i)\WLeadership skills\W      2  0.00
# 9   Interpersonal skills  (?i)\WInterpersonal skills\W     47  0.09
# 10       Time Management       (?i)\WTime Management\W     14  0.03
# 11     Critical Thinking     (?i)\WCritical Thinking\W     28  0.05
# 12          Adaptability          (?i)\WAdaptability\W      3  0.01

# %%
# Plot 

x = soft_skill_df.sort_values(by = 'ptg')
ax =x['ptg'].plot(kind = "barh",figsize = (10,5))
ax.set_title('Soft Skills as Percentage of Total Job Description', size = 15)
ax.set_yticklabels(x['skill'], size = 12)
ax.set_xticklabels(['{:.0%}'.format(x) for x in ax.get_xticks()])
plt.show()
